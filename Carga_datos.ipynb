# %% [markdown]
# ## Carga de datos

# %% [markdown]
# A continuación, se va a proceder a extraer la información que será objeto de estudio para el análisis.
# Para ello, se ha hecho uso de dos URLs:
# - El coste de vida se extraerá de la página https://es.numbeo.com/coste-de-vida/iniciar-p%C3%A1gina
# - La calidad de vida se extraerá de la página https://es.numbeo.com/calidad-de-vida/iniciar-p%C3%A1gina
#
# En ambos casos, se ha obtenido la información relativa a Europa.

# %% [markdown]
# ### Coste de vida

# %%
import pandas as pd
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import lxml

inicio = 2009
fin = 2023  
 
df_cost = pd.DataFrame()

#Para cada año (i), se carga la tabla de coste de vida
 
for i in range(inicio, fin + 1):
    url = f"http://es.numbeo.com/coste-de-vida/clasificaciones?title={i}"
    df_temp_cost = pd.read_html(url)[1:][0]
    df_temp_cost['Año'] = i
    df_cost = df_cost.append(df_temp_cost, ignore_index=True)
# Out:
# /var/folders/8z/h0j8wm9n0wnflk1qyrnnps840000gn/T/ipykernel_19817/2602375967.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cost = df_cost.append(df_temp_cost, ignore_index=True)
# /var/folders/8z/h0j8wm9n0wnflk1qyrnnps840000gn/T/ipykernel_19817/2602375967.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cost = df_cost.append(df_temp_cost, ignore_index=True)
# /var/folders/8z/h0j8wm9n0wnflk1qyrnnps840000gn/T/ipykernel_19817/2602375967.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cost = df_cost.append(df_temp_cost, ignore_index=True)
# /var/folders/8z/h0j8wm9n0wnflk1qyrnnps840000gn/T/ipykernel_19817/2602375967.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cost = df_cost.append(df_temp_cost, ignore_index=True)
# /var/folders/8z/h0j8wm9n0wnflk1qyrnnps840000gn/T/ipykernel_19817/2602375967.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cost = df_cost.append(df_temp_cost, ignore_index=True)
# /var/folders/8z/h0j8wm9n0wnflk1qyrnnps840000gn/T/ipykernel_19817/2602375967.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cost = df_cost.append(df_temp_cost, ignore_index=True)
# /var/folders/8z/h0j8wm9n0wnflk1qyrnnps840000gn/T/ipykernel_19817/2602375967.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cost = df_cost.append(df_temp_cost, ignore_index=True)
# /var/folders/8z/h0j8wm9n0wnflk1qyrnnps840000gn/T/ipykernel_19817/2602375967.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cost = df_cost.append(df_temp_cost, ignore_index=True)
# /var/folders/8z/h0j8wm9n0wnflk1qyrnnps840000gn/T/ipykernel_19817/2602375967.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cost = df_cost.append(df_temp_cost, ignore_index=True)
# /var/folders/8z/h0j8wm9n0wnflk1qyrnnps840000gn/T/ipykernel_19817/2602375967.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cost = df_cost.append(df_temp_cost, ignore_index=True)
# /var/folders/8z/h0j8wm9n0wnflk1qyrnnps840000gn/T/ipykernel_19817/2602375967.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cost = df_cost.append(df_temp_cost, ignore_index=True)
# /var/folders/8z/h0j8wm9n0wnflk1qyrnnps840000gn/T/ipykernel_19817/2602375967.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cost = df_cost.append(df_temp_cost, ignore_index=True)
# /var/folders/8z/h0j8wm9n0wnflk1qyrnnps840000gn/T/ipykernel_19817/2602375967.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cost = df_cost.append(df_temp_cost, ignore_index=True)
# /var/folders/8z/h0j8wm9n0wnflk1qyrnnps840000gn/T/ipykernel_19817/2602375967.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cost = df_cost.append(df_temp_cost, ignore_index=True)
# /var/folders/8z/h0j8wm9n0wnflk1qyrnnps840000gn/T/ipykernel_19817/2602375967.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cost = df_cost.append(df_temp_cost, ignore_index=True)

# %%
df_cost
# Out:
#       Puesto                 Ciudad  Índice de Costo de Vida  \
# 0        NaN         París, Francia                    12782
# 1        NaN        Dublín, Irlanda                    12660
# 2        NaN      Bruselas, Bélgica                    11753
# 3        NaN       Berlín, Alemania                    11525
# 4        NaN      Estocolmo, Suecia                    11248
# ...      ...                    ...                      ...
# 5994     NaN  Bucaramanga, Colombia                     1957
# 5995     NaN   Rawalpindi, Pakistán                     1638
# 5996     NaN   Faisalabad, Pakistán                     1608
# 5997     NaN       Multan, Pakistán                     1558
# 5998     NaN     Peshawar, Pakistán                     1509
#
#       Índice de Alquiler  Índice de Costo de Vida más Alquiler  \
# 0                   9639                                 11535
# 1                   8758                                 11112
# 2                   7877                                 10216
# 3                   3296                                  8261
# 4                   2999                                  7975
# ...                  ...                                   ...
# 5994                 457                                  1238
# 5995                 289                                   992
# 5996                 276                                   970
# 5997                 253                                   932
# 5998                 161                                   863
#
#       Índice de Comestibles  Índice de Precios en Restaurantes  \
# 0                     11705                              11653
# 1                     15451                              13156
# 2                     11088                              10756
# 3                      9027                               7919
# 4                      9895                               8525
# ...                     ...                                ...
# 5994                   1612                               1356
# 5995                   1474                               1255
# 5996                   1197                               1047
# 5997                   1512                               1101
# 5998                   1299                               1100
#
#       Índice de Poder Adquisitivo Local   Año
# 0                                  3938  2009
# 1                                  5925  2009
# 2                                  5558  2009
# 3                                  5858  2009
# 4                                  6387  2009
# ...                                 ...   ...
# 5994                               3133  2023
# 5995                               2792  2023
# 5996                               3252  2023
# 5997                               2189  2023
# 5998                               2764  2023
#
# [5999 rows x 9 columns]

# %%
#Guardamos el dataframe en un csv, dentro la carpeta input
df_cost.to_csv('inputs/costo_de_vida.csv', index=False)

# %% [markdown]
# ### Calidad de vida

# %% [markdown]
# Para extraer todos los datos de la calidad de vida, se han tenido que dividir los ficheros por años ya que la URL para los años 2012 y 2013 es diferente que para los años 2014 en adelante.

# %%
import pandas as pd
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

inicio = 2012
fin = 2013 
 
df_quality_1 = pd.DataFrame()
 
#Para cada año (i), se carga la tabla de calidad de vida
for i in range(inicio, fin + 1):
    url = f"https://es.numbeo.com/calidad-de-vida/clasificaciones?title={i}-Q1"
    df_temp_quality_1 = pd.read_html(url)[1:][0]
    df_temp_quality_1['Año'] = i
    df_quality_1 = df_quality_1.append(df_temp_quality_1, ignore_index=True)
# Out:
# /var/folders/8z/h0j8wm9n0wnflk1qyrnnps840000gn/T/ipykernel_19817/2661726438.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_quality_1 = df_quality_1.append(df_temp_quality_1, ignore_index=True)
# /var/folders/8z/h0j8wm9n0wnflk1qyrnnps840000gn/T/ipykernel_19817/2661726438.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_quality_1 = df_quality_1.append(df_temp_quality_1, ignore_index=True)

# %%
df_quality_1
# Out:
#      Puesto              Ciudad  Índice de Calidad de Vida  \
# 0       NaN    Berlín, Alemania                      21525
# 1       NaN       Zúrich, Suiza                      21318
# 2       NaN    Edmonton, Canadá                      20486
# 3       NaN    Perth, Australia                      19600
# 4       NaN     Calgary, Canadá                      19078
# ..      ...                 ...                        ...
# 156     NaN    El Cairo, Egipto                       -824
# 157     NaN  Yakarta, Indonesia                      -1303
# 158     NaN       Teherán, Irán                      -1701
# 159     NaN   Manila, Filipinas                      -2057
# 160     NaN  Caracas, Venezuela                      -3418
#
#      Índice de Poder Adquisitivo  Índice de Seguridad  Índice de Sanidad  \
# 0                          14062                 7734               6481
# 1                          13631                 8385               7778
# 2                          12469                 5898               7889
# 3                          11834                 4875               8704
# 4                          12425                 7188               7042
# ..                           ...                  ...                ...
# 156                         2160                 5119               5648
# 157                         3165                 5173               3833
# 158                         3290                 4584               4398
# 159                         2665                 3364               8056
# 160                         2423                 1430               4444
#
#      Índice de Costo de Vida  Relación Precio/Ingresos para Propiedades  \
# 0                       8906                                        574
# 1                      16607                                        827
# 2                      11210                                        359
# 3                      14218                                        524
# 4                      11171                                        458
# ..                       ...                                        ...
# 156                     4517                                       1335
# 157                     5801                                       1493
# 158                     6152                                       1929
# 159                     4794                                       2816
# 160                    11512                                       1679
#
#      Índice de Tiempo de Desplazamiento en Tráfico  Índice de Contaminación  \
# 0                                             2300                     4000
# 1                                             2733                     2650
# 2                                             3533                     2125
# 3                                             2700                     1500
# 4                                             6200                     2508
# ..                                             ...                      ...
# 156                                           5875                     9636
# 157                                           5625                     9806
# 158                                           6100                     8990
# 159                                           5400                     8483
# 160                                           3875                     8038
#
#     Índice de Clima   Año
# 0                 -  2012
# 1                 -  2012
# 2                 -  2012
# 3                 -  2012
# 4                 -  2012
# ..              ...   ...
# 156               -  2013
# 157               -  2013
# 158               -  2013
# 159               -  2013
# 160               -  2013
#
# [161 rows x 12 columns]

# %%
import pandas as pd
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

inicio = 2014
fin = 2023
 
df_quality_2 = pd.DataFrame()
 
for i in range(inicio, fin + 1):
    url = f"https://es.numbeo.com/calidad-de-vida/clasificaciones?title={i}"
    df_temp_quality_2 = pd.read_html(url)[1:][0]
    df_temp_quality_2['Año'] = i
    df_quality_2 = df_quality_2.append(df_temp_quality_2, ignore_index=True)
# Out:
# /var/folders/8z/h0j8wm9n0wnflk1qyrnnps840000gn/T/ipykernel_19817/2404779081.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_quality_2 = df_quality_2.append(df_temp_quality_2, ignore_index=True)
# /var/folders/8z/h0j8wm9n0wnflk1qyrnnps840000gn/T/ipykernel_19817/2404779081.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_quality_2 = df_quality_2.append(df_temp_quality_2, ignore_index=True)
# /var/folders/8z/h0j8wm9n0wnflk1qyrnnps840000gn/T/ipykernel_19817/2404779081.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_quality_2 = df_quality_2.append(df_temp_quality_2, ignore_index=True)
# /var/folders/8z/h0j8wm9n0wnflk1qyrnnps840000gn/T/ipykernel_19817/2404779081.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_quality_2 = df_quality_2.append(df_temp_quality_2, ignore_index=True)
# /var/folders/8z/h0j8wm9n0wnflk1qyrnnps840000gn/T/ipykernel_19817/2404779081.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_quality_2 = df_quality_2.append(df_temp_quality_2, ignore_index=True)
# /var/folders/8z/h0j8wm9n0wnflk1qyrnnps840000gn/T/ipykernel_19817/2404779081.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_quality_2 = df_quality_2.append(df_temp_quality_2, ignore_index=True)
# /var/folders/8z/h0j8wm9n0wnflk1qyrnnps840000gn/T/ipykernel_19817/2404779081.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_quality_2 = df_quality_2.append(df_temp_quality_2, ignore_index=True)
# /var/folders/8z/h0j8wm9n0wnflk1qyrnnps840000gn/T/ipykernel_19817/2404779081.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_quality_2 = df_quality_2.append(df_temp_quality_2, ignore_index=True)
# /var/folders/8z/h0j8wm9n0wnflk1qyrnnps840000gn/T/ipykernel_19817/2404779081.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_quality_2 = df_quality_2.append(df_temp_quality_2, ignore_index=True)
# /var/folders/8z/h0j8wm9n0wnflk1qyrnnps840000gn/T/ipykernel_19817/2404779081.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_quality_2 = df_quality_2.append(df_temp_quality_2, ignore_index=True)

# %%
df_quality_2
# Out:
#       Puesto                            Ciudad  Índice de Calidad de Vida  \
# 0        NaN               Canberra, Australia                      23698
# 1        NaN                    Ottawa, Canadá                      21877
# 2        NaN      Fráncfort del Óder, Alemania                      21497
# 3        NaN                     Zúrich, Suiza                      20821
# 4        NaN  Denver, Colorado, Estados Unidos                      20594
# ...      ...                               ...                        ...
# 1945     NaN                     Teherán, Irán                       6160
# 1946     NaN                   Daca, Bangladés                       5746
# 1947     NaN                    Beirut, Líbano                       5677
# 1948     NaN                    Lagos, Nigeria                       4839
# 1949     NaN                 Manila, Filipinas                       4497
#
#       Índice de Poder Adquisitivo  Índice de Seguridad  Índice de Sanidad  \
# 0                           13266                 6447               8185
# 1                           13188                 7609               6864
# 2                           13918                 7248               6310
# 3                           12464                 7890               7561
# 4                           13398                 6040               8259
# ...                           ...                  ...                ...
# 1945                         1891                 4408               5265
# 1946                         2590                 3682               4014
# 1947                         1008                 5366               6515
# 1948                          763                 3248               4635
# 1949                         2484                 3459               6371
#
#       Índice de Costo de Vida  Relación Precio/Ingresos para Propiedades  \
# 0                       10265                                        463
# 1                        8615                                        490
# 2                        9657                                        507
# 3                       15747                                        869
# 4                        8210                                        181
# ...                       ...                                        ...
# 1945                     3325                                       2897
# 1946                     2956                                       1537
# 1947                     8033                                       4132
# 1948                     3876                                       1220
# 1949                     3790                                       3760
#
#       Índice de Tiempo de Desplazamiento en Tráfico  Índice de Contaminación  \
# 0                                              1080                     1476
# 1                                              4000                     2246
# 2                                              2875                     3129
# 3                                              2480                     1714
# 4                                              4333                     3793
# ...                                             ...                      ...
# 1945                                           5291                     8096
# 1946                                           6097                     9347
# 1947                                           3982                     9372
# 1948                                           6822                     8926
# 1949                                           5364                     8992
#
#      Índice de Clima   Año
# 0                  -  2014
# 1                  -  2014
# 2                  -  2014
# 3                  -  2014
# 4                  -  2014
# ...              ...   ...
# 1945            7099  2023
# 1946            7129  2023
# 1947            9474  2023
# 1948            6075  2023
# 1949            6123  2023
#
# [1950 rows x 12 columns]

# %% [markdown]
# Igualmente, debido a que el mayor volumen de información que se ha observado se da en los años 2014 en adelante, solo vamos a guardar el fichero que contiene estos años, ya que se asume que es un horizonte temporal suficiente y así disponemos de la máxima información posible para todas las capitales.

# %%
#Guardamos en csv el dataframe que vamos a usar, dentro de inputs
df_quality_2.to_csv('inputs/calidad_de_vida.csv', index=False)
